# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/ADMIN/Documents/img/01/3.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=567x611>

# %%
region = (100, 75, 175, 175)
crop_img = img.crop(region)
display(crop_img)
# Out:
# <PIL.Image.Image image mode=RGB size=75x100>

# %%
paste_position = (150, 150)
img.paste(crop_img, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=567x611>
