# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/ADMIN/Documents/img/01/3.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=567x611>

# %%
rotate_img = img.rotate(90)
display(rotate_img)
# Out:
# <PIL.Image.Image image mode=RGB size=567x611>

# %%
transposed_img = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=611x567>
