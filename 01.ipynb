# %%
from PIL import Image

# %%
dir = 'C:/Users/ADMIN/Documents/img/01'

# %%
image_path = dir + '/1.jpg'
print(image_path)
# Out:
# C:/Users/ADMIN/Documents/img/01/1.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x736>

# %%
print("Đinh dạng ảnh: ", img01.format)
# Out:
# Đinh dạng ảnh:  JPEG

# %%
print("Kích thước ảnh: ", img01.size)
# Out:
# Kích thước ảnh:  (736, 736)

# %%
new_img_01_path = dir + '/new_01.jpg'
new_img_png_01_path = dir + '/new_01.png'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
