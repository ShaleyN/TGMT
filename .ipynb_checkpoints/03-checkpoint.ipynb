# %%
from PIL import Image
from imgtools import *

# %%
dir = 'C:/Users/ADMIN/Documents/img/01'

# %%
image_path = dir + '/5.jpg'
print(image_path)
img = Image.open(image_path)
# Out:
# C:/Users/ADMIN/Documents/img/01/5.jpg

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x736>

# %%
print(img.size)
# Out:
# (736, 736)

# %%
# Thay đổi kích thước
thumbnail_size = (100, 100)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100>

# %%
# Lưu ảnh
new_thumbnail_size_path = dir + "/new_img_thumbnail.JPG"
img.save(new_thumbnail_size_path)
